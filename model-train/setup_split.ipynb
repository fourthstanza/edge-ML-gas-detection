# %% [markdown]
# This code is the entry to the pipeline. Use it to set up indices of the datasplit and save them to a file for use across multiple sessions.

# %%
from pathlib import Path

ROOT_DIR = Path.cwd().parent
DATA_DIR = ROOT_DIR.joinpath('data')
INDICES_DIR = ROOT_DIR.joinpath("saved_indices")

from csv_to_pd import csvToDf
from data_ingestion import setup_split

# %%
splt = setup_split()
print("Length of train, test, and validation sets:", len(splt.train), len(splt.test), len(splt.val))
splt.export_indices()
